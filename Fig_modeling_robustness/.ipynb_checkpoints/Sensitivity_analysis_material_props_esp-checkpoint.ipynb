# %%
from aftershock_analysis import *
import copy
set_plot_formatting()

# %% [markdown]
# #### INPUTS

# %%
# Building results file
building_id = ['ID1012_good', 'ID1012', 'ID1012_bad']
n_stories = 8
# building_id = ['ID1021_bad', 'ID1021', 'ID1021_good']
# n_stories = 20
im = 'sa_avg'

# Damage indicator names
di_types = ["$SDR_{peak}$", "$RSDR_{peak}$", "$FDI_{peak}$", "DI hinges", "$DI_{sdr}$"]

# Minimum value of each damage indicator to consider
di_min = [1e-4, 1e-6, 1e-7, 1e-6, 1e-6, 1e-6, 1e-6, 1e-6, 1e-6]

# Transformation for fit and display
di_transformation = "log"

n_scales = 7
n_mainshocks = 44

# %% [markdown]
# Color for each building

# %%
grayscale = False
n_colors = 3
min_intensity = 0.85
max_intensity = 0.5

color_values = np.linspace(min_intensity, max_intensity, n_colors)
color_palettes = ['Greens', 'Blues', 'Reds']
color_build = [mpl.cm.get_cmap(color_palettes[i])(color_values[i]) for i in range(len(color_values))] 
check_colors(color_build, 10)

# %% [markdown]
# # Retrieve damage indicator data per buildng

# %%
damage_instances_data = dict()
for b_i in building_id:
    damage_instances_data[b_i] = pd.read_hdf('../Postprocessed_results/Damage_Instances_' 
                                             + b_i[0:6] + '_mat_props.h5', key=b_i)

# %% [markdown]
# ##### Assemble Damage Indicator Matrix per building [check manually those related to fractions of damaged components]

# %%
damage_instances_matrix = dict()

for b_i in building_id:
    # Retrieve data of current building
    current_building = damage_instances_data[b_i]
    
    # Matrix of Damage Indicators per damage instance        
    di_matrix = current_building[di_types[0]]
    di_matrix = np.vstack((di_matrix, current_building[di_types[1]]))
    di_matrix = np.vstack((di_matrix, current_building[di_types[2]]))
    di_matrix = np.vstack((di_matrix, current_building[di_types[3]]))
    di_matrix = np.vstack((di_matrix, current_building[di_types[4]]))
    
    damage_instances_matrix[b_i] = copy.deepcopy(np.transpose(di_matrix))
del(di_matrix)

# %% [markdown]
# # Pushover curves

# %% [markdown]
# #### Import pushover

# %%
push_curves = dict()

for b_i in building_id:
    pushover = pd.read_excel('../Postprocessed_results/' + b_i + '.xls')
    push_curves[b_i] = copy.deepcopy(pushover)
    
    
color_build = ['tab:blue', 'k', 'tab:orange']

# %%
x_push_limits = [0, 60]
y_push_limits = [0, 0.25]
linewidth = 2
labels = ['Calidad Alta','Calidad media','Calidad baja']

fig = plt.figure(figsize=(7, 5))

for i, b_i in enumerate(building_id):
    _ = plt.plot(push_curves[b_i].RoofDrift*100, push_curves[b_i].FxRatio, color=color_build[i], 
                 linewidth=3, label=labels[i])

# Formatting
_ = plt.xlim(x_push_limits)
_ = plt.ylim(y_push_limits)
_ = plt.legend()
_ = plt.grid(which='both', alpha = 0.3)
_ = plt.title('Curvas de capacidad del edificio', loc='right')
_ = plt.ylabel('Coeficiente de fuerza lateral = $V_s/W$')
_ = plt.xlabel('Deriva de cubierta [%]')

plt.tight_layout()

_ = plt.savefig('pushover_curves.png', dpi=500, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Comparison of Damage Indicators

# %% [markdown]
# #### Reduction in median collapse capacity

# %%
k_min = 0.2

k = dict()

for b_i in building_id:
    # Retrieve data of current building
    k[b_i] = damage_instances_data[b_i]['$\kappa$'].values    
    damage_instances_matrix[b_i] = damage_instances_matrix[b_i][k[b_i] > k_min]
    damage_instances_data[b_i] = damage_instances_data[b_i][k[b_i] > k_min]
    k[b_i] = k[b_i][k[b_i] > k_min]

y_label = 'Fraction of $\widehat{Sa}_{collapse}^{Intact}$, $\kappa$'

# %% [markdown]
# #### Fit three-linear curve

# %%
parameters = dict()
N_seeds = 20

for b_i in building_id:
    parameters_bi = pd.DataFrame()
    
    for j, di in enumerate(di_types):        
        temp = fitPieceWiseFunc3LinLS(di, damage_instances_matrix[b_i][:, j], k[b_i], di_min[j], di_transformation, N_seeds)
    
        parameters_bi = parameters_bi.append(temp)
        print(b_i + ' ' + di)
        
    parameters[b_i] = copy.deepcopy(parameters_bi)
    parameters[b_i]
    
del(parameters_bi)
# Out:
# ID1012_good $SDR_{peak}$
# ID1012_good $RSDR_{peak}$
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:999: RuntimeWarning: invalid value encountered in double_scalars
#   b1_0 = np.sum(x1.dot(y1)) / np.sum(x1.dot(x1))
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:808: RuntimeWarning: invalid value encountered in greater
#   y_seg1 = y[np.logical_and(x > param[1], x <= param[2])]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:808: RuntimeWarning: invalid value encountered in less_equal
#   y_seg1 = y[np.logical_and(x > param[1], x <= param[2])]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:809: RuntimeWarning: invalid value encountered in greater
#   y_seg2 = y[x > param[2]]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:811: RuntimeWarning: invalid value encountered in greater
#   y_pred_seg1 = y_pred[np.logical_and(x > param[1], x <= param[2])]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:811: RuntimeWarning: invalid value encountered in less_equal
#   y_pred_seg1 = y_pred[np.logical_and(x > param[1], x <= param[2])]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:812: RuntimeWarning: invalid value encountered in greater
#   y_pred_seg2 = y_pred[x > param[2]]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:814: RuntimeWarning: invalid value encountered in greater
#   x_seg1 = x[np.logical_and(x > param[1], x <= param[2])]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:814: RuntimeWarning: invalid value encountered in less_equal
#   x_seg1 = x[np.logical_and(x > param[1], x <= param[2])]
# C:\Users\Francisco\Documents\GitHub\aftershock_analysis\aftershock_analysis\damage_indicators.py:815: RuntimeWarning: invalid value encountered in greater
#   x_seg2 = x[x > param[2]]
# ID1012_good $FDI_{peak}$
# ID1012_good DI hinges
# ID1012_good $DI_{sdr}$
#                Minimum limit  Threshold limit   Slope 1   Slope 2     k_max  \
# $SDR_{peak}$       -3.954041        -2.895566 -0.162280 -0.425620  1.012519
# $RSDR_{peak}$      -5.956199        -3.494033 -0.055352 -0.292699  0.991268
# $FDI_{peak}$       -4.852872        -1.865341 -0.039650 -0.272467  1.010519
# DI hinges          -4.565988        -0.588964 -0.032748 -0.323846  1.013295
# $DI_{sdr}$         -6.387286        -1.822369 -0.028626 -0.295839  1.013003
#
#                std_residuals  \
# $SDR_{peak}$        0.085828
# $RSDR_{peak}$       0.091218
# $FDI_{peak}$        0.083304
# DI hinges           0.084567
# $DI_{sdr}$          0.086366
#
#                                                        Residuals  \
# $SDR_{peak}$   [0.019225072613819005, 0.09010727884840031, 0....
# $RSDR_{peak}$  [0.04047641759722009, 0.056852054850133116, 0....
# $FDI_{peak}$   [0.021225320566807593, 0.07733889835199903, 0....
# DI hinges      [0.018448578551458095, 0.0967639749283633, 0.1...
# $DI_{sdr}$     [0.018740942516719983, 0.06091399474089654, 0....
#
#                       x_min  \
# $SDR_{peak}$   1.000000e-04
# $RSDR_{peak}$  1.000000e-06
# $FDI_{peak}$   1.000000e-07
# DI hinges      1.000000e-06
# $DI_{sdr}$     1.000000e-06
#
#                                                      di for plot  \
# $SDR_{peak}$   [0.0058378399999999995, 0.019177055327094787, ...
# $RSDR_{peak}$  [0.00012139000000000011, 0.002589738007924236,...
# $FDI_{peak}$   [9.999999999999994e-08, 0.007805926201553085, ...
# DI hinges      [1.0000000000000004e-06, 0.010399601022068695,...
# $DI_{sdr}$     [1.0000000000000004e-06, 0.0016828177692182007...
#
#                                                       k for plot
# $SDR_{peak}$   [1.0125189197356046, 1.0125189197356046, 0.840...
# $RSDR_{peak}$  [0.9912675747522035, 0.9912675747522035, 0.854...
# $FDI_{peak}$   [1.010518671782616, 1.010518671782616, 0.89206...
# DI hinges      [1.0132954137979655, 1.0132954137979655, 0.883...
# $DI_{sdr}$     [1.0130030498327036, 1.0130030498327036, 0.882...
# ID1012 $SDR_{peak}$
# ID1012 $RSDR_{peak}$
# ID1012 $FDI_{peak}$
# ID1012 DI hinges
# ID1012 $DI_{sdr}$
#                Minimum limit  Threshold limit   Slope 1   Slope 2     k_max  \
# $SDR_{peak}$       -4.615780        -3.690468 -0.096129 -0.338462  1.015024
# $RSDR_{peak}$      -6.772023        -4.049977 -0.054123 -0.279984  1.005147
# $FDI_{peak}$       -4.914963        -1.762894 -0.034276 -0.288712  1.013471
# DI hinges          -4.796280        -0.479485 -0.026809 -0.316076  1.014893
# $DI_{sdr}$         -6.361830        -1.673526 -0.027585 -0.325974  1.016179
#
#                std_residuals  \
# $SDR_{peak}$        0.084902
# $RSDR_{peak}$       0.086225
# $FDI_{peak}$        0.079423
# DI hinges           0.083887
# $DI_{sdr}$          0.082109
#
#                                                        Residuals  \
# $SDR_{peak}$   [0.040542846409081124, 0.07794839662995434, 0....
# $RSDR_{peak}$  [0.05041955302902257, 0.06963964100602638, 0.1...
# $FDI_{peak}$   [0.042095621360416446, 0.08461584707190983, 0....
# DI hinges      [0.04067430947530881, 0.09231043864459432, 0.0...
# $DI_{sdr}$     [0.03938814597352214, 0.07295653582009065, 0.0...
#
#                       x_min  \
# $SDR_{peak}$   1.000000e-04
# $RSDR_{peak}$  1.000000e-06
# $FDI_{peak}$   1.000000e-07
# DI hinges      1.000000e-06
# $DI_{sdr}$     1.000000e-06
#
#                                                      di for plot  \
# $SDR_{peak}$   [0.003451720000000001, 0.00989446604223277, 0....
# $RSDR_{peak}$  [1.4141999999999996e-05, 0.0011453756911606354...
# $FDI_{peak}$   [9.999999999999994e-08, 0.007335987169137981, ...
# DI hinges      [1.0000000000000004e-06, 0.00826041628519802, ...
# $DI_{sdr}$     [1.0000000000000004e-06, 0.001726204731571811,...
#
#                                                       k for plot
# $SDR_{peak}$   [1.0150241625121486, 1.0150241625121486, 0.926...
# $RSDR_{peak}$  [1.005147455892207, 1.005147455892207, 0.85782...
# $FDI_{peak}$   [1.0134713875608132, 1.0134713875608132, 0.905...
# DI hinges      [1.0148926994459209, 1.0148926994459209, 0.899...
# $DI_{sdr}$     [1.0161788629477075, 1.0161788629477075, 0.886...
# ID1012_bad $SDR_{peak}$
# ID1012_bad $RSDR_{peak}$
# ID1012_bad $FDI_{peak}$
# ID1012_bad DI hinges
# ID1012_bad $DI_{sdr}$
#                Minimum limit  Threshold limit   Slope 1   Slope 2     k_max  \
# $SDR_{peak}$       -5.308704        -4.082920 -0.069423 -0.419896  1.012535
# $RSDR_{peak}$      -7.279242        -4.411567 -0.055091 -0.336836  0.993598
# $FDI_{peak}$       -3.944226        -1.473462 -0.044184 -0.434221  1.000946
# DI hinges          -4.375177        -0.366836 -0.025030 -0.320955  1.003888
# $DI_{sdr}$         -5.695307        -1.391205 -0.031314 -0.529895  1.006206
#
#                std_residuals  \
# $SDR_{peak}$        0.084048
# $RSDR_{peak}$       0.093337
# $FDI_{peak}$        0.074928
# DI hinges           0.089537
# $DI_{sdr}$          0.077936
#
#                                                        Residuals  \
# $SDR_{peak}$   [0.029674204462934894, 0.09637421008348224, 0....
# $RSDR_{peak}$  [0.030076158344171655, 0.10876603366153015, 0....
# $FDI_{peak}$   [0.022728664482092542, 0.11521691453519944, 0....
# DI hinges      [0.019787107651765723, 0.11060773145227243, 0....
# $DI_{sdr}$     [0.01746910568727289, 0.10618276857017006, 0.0...
#
#                       x_min  \
# $SDR_{peak}$   1.000000e-04
# $RSDR_{peak}$  1.000000e-06
# $FDI_{peak}$   1.000000e-07
# DI hinges      1.000000e-06
# $DI_{sdr}$     1.000000e-06
#
#                                                      di for plot  \
# $SDR_{peak}$   [0.002125849999999999, 0.004948333191657384, 0...
# $RSDR_{peak}$  [3.3970000000000015e-05, 0.0006897084759785989...
# $FDI_{peak}$   [9.999999999999994e-08, 0.019366208738860365, ...
# DI hinges      [1.0000000000000004e-06, 0.012585910310433846,...
# $DI_{sdr}$     [1.0000000000000004e-06, 0.003361703551810201,...
#
#                                                       k for plot
# $SDR_{peak}$   [1.0125348984981166, 1.0125348984981166, 0.927...
# $RSDR_{peak}$  [0.9935984585638508, 0.9935984585638508, 0.835...
# $FDI_{peak}$   [1.0009459524259299, 1.0009459524259299, 0.891...
# DI hinges      [1.0038875092562567, 1.0038875092562567, 0.903...
# $DI_{sdr}$     [1.0062055112207495, 1.0062055112207495, 0.871...

# %%
for b_i in building_id:
    parameters_bi = parameters[b_i]
    parameters_bi.to_hdf('kappa_function__ID1021_mat_props.h5', key=b_i)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['Residuals', 'di for plot', 'k for plot']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
import matplotlib.transforms as transforms

# Concatenate results for all buildings
################### Regression lines to compare ##########################
di_to_plot = ["$SDR_{peak}$", "$RSDR_{peak}$", "DI hinges", "$DI_{sdr}$"]
x_limits = [[0.001, 0.1], [1e-4, 0.1], [1e-3, 5], [1e-3, 1]]
# di_to_plot = ["$SDR_{peak}$", "$RSDR_{peak}$", "$FDI_{peak}$", "$DI_{sdr}$"]
# x_limits = [[0.001, 0.1], [1e-4, 0.1], [1e-3, 1], [1e-3, 1]]

building_id = [building_id[2], building_id[1], building_id[0]]
labels = [labels[2], labels[1], labels[0]]
color_build = [color_build[2], color_build[1], color_build[0]]
##########################################################################

fig = plt.figure(figsize=(14, 4))

for j, di in enumerate(di_to_plot):
    # Locate the subplot
    ax = plt.subplot2grid((1, 4), (0, j), rowspan=1, colspan=1)
    
    # Plot each lines
    for i, b_i in enumerate(building_id):
        a_plot = parameters[b_i].loc[[di]]['di for plot'][0]
        k_plot = parameters[b_i].loc[[di]]['k for plot'][0]
        _ = plt.plot(a_plot, k_plot, Color=color_build[i], label=labels[i])
        _ = plt.plot([a_plot[2], a_plot[2]], [0, 1.1], linestyle='--', Color=color_build[i], label='_nolegend_')
        
        # Title
        if di == '$SDR_{peak}$' or di == '$RSDR_{peak}$':
            title_text = "$a_2$ = " + str(round(a_plot[2]*100,1)) + '%'
        else:
            title_text = "$a_2$ = " + str(round(a_plot[2],2))
            
        _ = plt.figtext(0.175 + j*0.21, 0.18+0.05*i, title_text , ha="center", 
                        va="bottom",color=color_build[i], fontsize=12)
        
    # Formatting
    _ = plt.xlabel(di_to_plot[j])
    if j == 0:
        _ = plt.ylabel(y_label)

    if j == 3:
        _ = plt.legend(bbox_to_anchor=(0, -0.25), ncol=3)
        
    _ = plt.xlim(x_limits[j])
    _ = plt.ylim([0.4, 1.1])
    _ = plt.xscale('log')
    _ = plt.gca()
    _ = ax.xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda y, _: '{:.2g}'.format(y)))
    _ = plt.grid(which='major', alpha=0.3)
    plt.subplots_adjust(wspace=0.3)

plt.tight_layout()

bounds_print = transforms.Bbox([[0, -1], [13, 4]])
plt.savefig('Regression_lines_materials.pdf', bbox_inches = bounds_print)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
